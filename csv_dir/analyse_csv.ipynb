# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
csv_files_list = glob.glob("*.csv")

# %%
len(csv_files_list)
# Out:
# 2

# %%
# csv_files_list = csv_files_list[24:]

# %%
csv_files_dict = {}
for file in csv_files_list:
    csv_files_dict[file] = pd.read_csv(file,header=None,nrows = 200,names=['train_acc','valid_acc'])

# %%
plt.rcParams['figure.figsize'] = [20, 10]
for key,val in csv_files_dict.items():
    plt.plot(val.train_acc,label=key)
    plt.legend(loc="upper left")
    plt.title('Training Accuracy Comparison')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [20, 10]
for key,val in csv_files_dict.items():
    plt.plot(val.valid_acc,label=key)
    plt.legend(loc="upper left")
    plt.title('Validation Accuracy Comparison')
plt.show()
